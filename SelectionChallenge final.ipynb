# %% [markdown]
# <a href="https://colab.research.google.com/github/Chenjing2022/Chenjing2022/blob/main/SelectionChallenge%20final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Three selection challenges
#
# ---

# %% [markdown]
# ### Challenge 1 - password format
#
# Write a function called **check_password_valid()** which will check the validity of a **password** input by a user.
#
# Rules for a valid password are:
#
# *  At least 1 letter between [a-z] and 1 letter between [A-Z].
# *  At least 1 number between [0-9].
# *  At least 1 character from [$#@].
# *  Minimum length 6 characters.
# *  Maximum length 16 characters.
#
# Let the user know if the `password` they have typed is valid and, if not, where was the first error.
#
# *Hint:  to test if a set of characters is present in a password String, you can use re.search('[character set]', `password`)*
#
# Example:
# *if re.search('[a-z]',`password`):*
# this will be True if there is at least 1 character a-z in the password.
#
# **re** is a pre-written Python function for pattern searching in Strings.  It has been imported for you in the code cell below.

# %%
import re

# add your check_PasswordValid() function and call below here
def check_password_valid():
  password = str(input("please enter your password: "))
  if len(password) < 6:
    print("Your password is too short")
  elif len(password) > 16:
    print("Your password is too long")
  else:
    if re.search('[a-z]',password):
      print("Invalid password. It should include at least 1 lower case letter.")
    elif re.search('[A-Z]',password):
      print("Invalid password. It should include at least 1 upper case letter.")
    elif re.search('[0-9]',password):
      print("Invalid password. It should include at least 1 digit number.")
    elif re.search('[$#@]',password):
      print("Invalid password. It should include at least 1 character.")
    else:
      print("Your password is valid")
check_password_valid()
# Out:
# please enter your password: asddff
# Invalid password. It should include at least 1 lower case letter.

# %% [markdown]
# ---
# ### Challenge 2 - triangle shape
#
# Write a function called **evaluate_triangle_shape()** which will check if a triangle is equilateral, isosceles or scalene, based on the three side lengths entered by a user (**x**, **y** and **z**.
#
# An equilateral triangle is a triangle in which all three sides are equal.
# A scalene triangle is a triangle that has three unequal sides.
# An isosceles triangle is a triangle with (at least) two equal sides.
#
# For example:
# A triange with side lengths
# x: 6
# y: 8
# z: 12
# is a *Scalene triangle*
#
# A triangle with side lengths
# x:5
# y:3
# z:5
# is an *Isosceles triangle*

# %%
def evaluate_triangle_shape(x, y, z):
  # Function to check if the triangle
  # is equilateral or isosceles or scalene

  # Check for equilateral triangle
  if x == y == z:
    print("Equilateral triangle")
 
  # Check for isosceles triangle
  elif x == y or y == z or z == x:
    print("Isosceles triangle")
 
  # Otherwise scalene triangle
  else:
    print("Scalene triangle")
evaluate_triangle_shape(6, 6, 6)
# Out:
# Equilateral triangle

# %% [markdown]
# ---
# ### Challenge 3 - which season
#
# Write a function called **determine_season()** which will ask the user to enter two integers representing a **month** and **day** and prints the season for that month and day.
#
# Note:  for this exercise the season dates are:
# *  Winter December 21 to March 20
# *  Spring March 21 to June 20
# *  Summer June 21 to September 20
# *  Autumn September 21 to December 20
#
# Test input:
# Input the month (e.g. January, February etc.): 7
# Input the day: 31
#
# Expected output:
# Season is summer
#
# *Note: this will require multiple and or or operators and you should use brackets to help Python know which operations to do first*
#
# *For an extra challenge you can check that the day is valid for the month*

# %%
def determine_season():
  month = int(input("please input the month: "))
  day = int(input("please input the day: "))
  #if month in range(1,13) and day in range(1,32):
  if ((month == 4 or month == 6 or month ==9 or month ==11) and day <=30) or ((month == 2) and day <=29) or ((month == 1 or month == 3 or month == 5 or month ==7 or month ==8 or month == 10 or month == 12) and day <=31):
    if (month == 12 and day >=21) or (month == 1 or month == 2) or (month == 3 and day <=20):
      print("season is Winter")
    elif (month == 3 and day >=21) or (month == 4 or month == 5) or (month == 6 and day <=20):
      print("season is Spring")
    elif (month == 6 and day >=21) or (month == 7 or month == 8) or (month == 9 and day <=20):
      print("season is Summer")
    elif (month == 9 and day >=21) or (month == 10 or month == 11) or (month == 12 and day <=20):
      print("season is Autumn")
  else:
    print("Invalid inputs")
determine_season()
# Out:
# please input the month: 2
# please input the day: 28
# season is Winter
